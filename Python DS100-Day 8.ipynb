# %%
import pandas as pd

# %%
nba_data=pd.read_csv("F:/Pandas/nba.csv")
nba_data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba_data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba_data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba_data.shape
# Out:
# (458, 9)

# %%
nba_data.ndim
# Out:
# 2

# %%
nba_data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# Selecting a column in the dataset

# %%
nba_data.Position
# Out:
# 0       PG
# 1       SF
# 2       SG
# 3       SG
# 4       PF
#       ...
# 453     PG
# 454     PG
# 455      C
# 456      C
# 457    NaN
# Name: Position, Length: 458, dtype: object

# %%
nba_data.Age
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
#        ...
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# 457     NaN
# Name: Age, Length: 458, dtype: float64

# %% [markdown]
# Alternate way

# %%
nba_data[['Weight','Number']]
# Out:
#      Weight  Number
# 0     180.0     0.0
# 1     235.0    99.0
# 2     205.0    30.0
# 3     185.0    28.0
# 4     231.0     8.0
# ..      ...     ...
# 453   203.0     8.0
# 454   179.0    25.0
# 455   256.0    21.0
# 456   231.0    24.0
# 457     NaN     NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# Select a specific column and row

# %%
nba_data['Weight'][0]
# Out:
# 180.0

# %% [markdown]
# Selecting using loc method

# %%
nba_data.loc[:,'Weight']
# Out:
# 0      180.0
# 1      235.0
# 2      205.0
# 3      185.0
# 4      231.0
#        ...
# 453    203.0
# 454    179.0
# 455    256.0
# 456    231.0
# 457      NaN
# Name: Weight, Length: 458, dtype: float64

# %%
nba_data.loc[:,['Weight','Age']]
# Out:
#      Weight   Age
# 0     180.0  25.0
# 1     235.0  25.0
# 2     205.0  27.0
# 3     185.0  22.0
# 4     231.0  29.0
# ..      ...   ...
# 453   203.0  26.0
# 454   179.0  24.0
# 455   256.0  26.0
# 456   231.0  26.0
# 457     NaN   NaN
#
# [458 rows x 2 columns]

# %%
nba_data.loc[[1,2,3,4,5],['Weight','Age']]
# Out:
#    Weight   Age
# 1   235.0  25.0
# 2   205.0  27.0
# 3   185.0  22.0
# 4   231.0  29.0
# 5   240.0  29.0

# %%
nba_data.loc[:5,['Weight','Age']]
# Out:
#    Weight   Age
# 0   180.0  25.0
# 1   235.0  25.0
# 2   205.0  27.0
# 3   185.0  22.0
# 4   231.0  29.0
# 5   240.0  29.0

# %%
nba_data.loc[245:315,['Weight','Age']]
# Out:
#      Weight   Age
# 245   186.0  30.0
# 246   240.0  22.0
# 247   230.0  22.0
# 248   200.0  27.0
# 249   220.0  26.0
# ..      ...   ...
# 311   190.0  35.0
# 312   245.0  30.0
# 313   235.0  31.0
# 314   212.0  35.0
# 315   246.0  31.0
#
# [71 rows x 2 columns]

# %% [markdown]
# 1.loc method includes the last element in the range
# 2.iloc method does not includes the last element in the range

# %% [markdown]
# Using iloc

# %%
nba_data.iloc[:10,1:3]
# Out:
#              Team  Number
# 0  Boston Celtics     0.0
# 1  Boston Celtics    99.0
# 2  Boston Celtics    30.0
# 3  Boston Celtics    28.0
# 4  Boston Celtics     8.0
# 5  Boston Celtics    90.0
# 6  Boston Celtics    55.0
# 7  Boston Celtics    41.0
# 8  Boston Celtics    12.0
# 9  Boston Celtics    36.0

# %% [markdown]
# Using condition

# %%
nba_data.loc[nba_data.Weight==231]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 205     C.J. Miles  Indiana Pacers     0.0       SF  29.0    6-6   231.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#     College     Salary
# 4       NaN  5000000.0
# 205     NaN  4394225.0
# 456  Kansas   947276.0

# %%
nba_data.Weight==231
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 453    False
# 454    False
# 455    False
# 456     True
# 457    False
# Name: Weight, Length: 458, dtype: bool

# %%
nba_data.loc[(nba_data.Weight>231) & (nba_data.Age > 20.0)]
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 1        Jae Crowder          Boston Celtics    99.0       SF  25.0    6-6
# 5       Amir Johnson          Boston Celtics    90.0       PF  29.0    6-9
# 6      Jordan Mickey          Boston Celtics    55.0       PF  21.0    6-8
# 7       Kelly Olynyk          Boston Celtics    41.0        C  25.0    7-0
# 10   Jared Sullinger          Boston Celtics     7.0        C  24.0    6-9
# ..               ...                     ...     ...      ...   ...    ...
# 435   Meyers Leonard  Portland Trail Blazers    11.0       PF  24.0    7-1
# 439    Mason Plumlee  Portland Trail Blazers    24.0        C  26.0   6-11
# 446   Derrick Favors               Utah Jazz    15.0       PF  24.0   6-10
# 447      Rudy Gobert               Utah Jazz    27.0        C  23.0    7-1
# 455     Tibor Pleiss               Utah Jazz    21.0        C  26.0    7-3
#
#      Weight       College      Salary
# ...

# %%
nba_data.loc[(nba_data.Weight>231) | (nba_data.Age > 20.0)]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Identifies the rows that are null

# %%
nba_data.loc[nba_data.Weight.notnull()]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba_data.loc[nba_data.Weight.isnull()]
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %% [markdown]
# Assign the value

# %%
nba_data['EdgeCompute']=45

# %%
nba_data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  EdgeCompute
# ...
